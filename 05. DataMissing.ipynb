# %% [markdown]
# <a href="https://colab.research.google.com/github/GTD2101-ACD-AA-EJ23/03-Pandas-20170749/blob/main/05.%20DataMissing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tipos de Datos y Valores Extraviados
#
# En este JNB se revisará el tema de Tipos de Datos y Valores Extraviados en Pandas.

# %%
import pandas as pd
reviews = pd.read_csv("https://raw.githubusercontent.com/GTD2101-ACD-AA-EJ23/03-Pandas-20170749/main/data/winemag-data-130k-v2.csv", index_col=0)
#pd.set_option('max_rows', 5)

# %%
reviews.price
# Out:
# 0          NaN
# 1         15.0
# 2         14.0
# 3         13.0
# 4         65.0
#           ...
# 129966    28.0
# 129967    75.0
# 129968    30.0
# 129969    32.0
# 129970    21.0
# Name: price, Length: 129971, dtype: float64

# %%
reviews.price.dtype
# Out:
# dtype('float64')

# %%
reviews.price.name
# Out:
# 'price'

# %%
reviews.price.count()
# Out:
# 120975

# %%
reviews.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
x=5

# %%
type(x)
# Out:
# int

# %%
reviews.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
# 2         87.0
# 3         87.0
# 4         87.0
#           ...
# 129966    90.0
# 129967    90.0
# 129968    90.0
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %%
reviews.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
reviews.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # Datos extraviados
# Es común que en los data sets no se tenga presencia de todos los datos. El saber sobre estoy y el tratamiento que damos a esta situación es fundamental.

# %%
reviews.isnull()
# Out:
#         country  description  designation  points  price  province  region_1  \
# 0         False        False        False   False   True     False     False
# 1         False        False        False   False  False     False      True
# 2         False        False         True   False  False     False     False
# 3         False        False        False   False  False     False     False
# 4         False        False        False   False  False     False     False
# ...         ...          ...          ...     ...    ...       ...       ...
# 129966    False        False        False   False  False     False      True
# 129967    False        False         True   False  False     False     False
# 129968    False        False        False   False  False     False     False
# 129969    False        False         True   False  False     False     False
# 129970    False        False        False   False  False     False     False
#
# ...

# %%
reviews.price.isnull()
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: price, Length: 129971, dtype: bool

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# ...        ...                                                ...
# 124176     NaN  This Swiss red blend is composed of four varie...
# 129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   30.0      NaN      NaN
# ...

# %%
reviews[reviews.country.isnull()]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# ...        ...                                                ...
# 124176     NaN  This Swiss red blend is composed of four varie...
# 129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   30.0      NaN      NaN
# ...

# %%
reviews.loc[reviews.country.isnull()]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# ...        ...                                                ...
# 124176     NaN  This Swiss red blend is composed of four varie...
# 129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   30.0      NaN      NaN
# ...

# %%
reviews[reviews.country.isnull() & reviews.price.isnull()]
# Out:
#       country                                        description  \
# 3131      NaN  Soft, fruity and juicy, this is a pleasant, si...
# 11348     NaN  Light and fruity, this is a wine that has some...
# 16749     NaN  Winemaker: Bartho Eksteen. This wooded Sauvy s...
# 57612     NaN  Winemaker: Gordon Newton Johnson. This is such...
#
#                                    designation  points  price province  \
# 3131                                  Partager      83    NaN      NaN
# 11348                                 Partager      82    NaN      NaN
# 16749  Cape Winemakers Guild Vloekskoot Wooded      91    NaN      NaN
# 57612          Cape Winemakers Guild Windansea      92    NaN      NaN
#
#       region_1 region_2    taster_name taster_twitter_handle  \
# 3131       NaN      NaN     Roger Voss            @vossroger
# 11348      NaN      NaN     Roger Voss            @vossroger
# 16749      NaN      NaN  Lauren Buzzeo             @laurbuzz
# ...

# %%
reviews.region_2.fillna("Unknown")
# Out:
# 0                   Unknown
# 1                   Unknown
# 2         Willamette Valley
# 3                   Unknown
# 4         Willamette Valley
#                 ...
# 129966              Unknown
# 129967         Oregon Other
# 129968              Unknown
# 129969              Unknown
# 129970              Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
reviews.price.fillna("Unknows")
# Out:
# 0         Unknows
# 1            15.0
# 2            14.0
# 3            13.0
# 4            65.0
#            ...
# 129966       28.0
# 129967       75.0
# 129968       30.0
# 129969       32.0
# 129970       21.0
# Name: price, Length: 129971, dtype: object

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0             @kerino
# 1          @vossroger
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
#              ...
# 129966            NaN
# 129967    @paulgwine
# 129968     @vossroger
# 129969     @vossroger
# 129970     @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object
